# %%
# %matplotlib inline

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(sum(map(ord, "aesthetics")))

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sinplot()

# %%
sns.set(style='whitegrid')

data = np.random.normal(size=(20, 6)) + np.arange(6) / 2

sns.boxplot(data=data);

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
sns.palplot(sns.color_palette("hls", 8))

# %%
sns.palplot(sns.color_palette("husl", 8))

# %%
sns.palplot(sns.color_palette("Paired"))

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))

# %%
plt.plot([3, 2], [2, 1], sns.xkcd_rgb["pale purple"], lw=3)
# plt.plot([1, 1], [0, 20], sns.xkcd_rgb["medium green"], lw=3)
# plt.plot([0, 1], [0, 3], sns.xkcd_rgb["denim blue"], lw=3);

colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
sns.palplot(sns.xkcd_palette(colors))

# %%
sns.palplot(sns.cubehelix_palette(9, start=2, rot=0, dark=0, light=.95, reverse=False))

# %%
x, y = np.random.multivariate_normal([0, 0], [[1, -.5], [-.5, 1]], size=300).T

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
sns.kdeplot(x, y, cmap=cmap, shade=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-e3d12d2e2dbe> in <module>()
#       1 cmap = sns.cubehelix_palette(light=1, as_cmap=True)
# ----> 2 sns.kdeplot(x, y, cmap=cmap, shade=True)
#
# /usr/local/lib/python2.7/site-packages/seaborn/distributions.pyc in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, ax, **kwargs)
#     598         ax = _bivariate_kdeplot(x, y, shade, shade_lowest,
#     599                                 kernel, bw, gridsize, cut, clip, legend,
# --> 600                                 ax, **kwargs)
#     601     else:
#     602         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#
# /usr/local/lib/python2.7/site-packages/seaborn/distributions.pyc in _bivariate_kdeplot(x, y, filled, fill_lowest, kernel, bw, gridsize, cut, clip, axlabel, ax, **kwargs)
#     364     # Calculate the KDE
#     365     if _has_statsmodels:
# --> 366         xx, yy, z = _statsmodels_bivariate_kde(x, y, bw, gridsize, cut, clip)
#     367     else:
#     368         xx, yy, z = _scipy_bivariate_kde(x, y, bw, gridsize, cut, clip)
#
# /usr/local/lib/python2.7/site-packages/seaborn/distributions.pyc in _statsmodels_bivariate_kde(x, y, bw, gridsize, cut, clip)
#     410         y = y.values
#     411
# --> 412     kde = smnp.KDEMultivariate([x, y], "cc", bw)
#     413     x_support = _kde_support(x, kde.bw[0], gridsize, cut, clip[0])
#     414     y_support = _kde_support(y, kde.bw[1], gridsize, cut, clip[1])
#
# /usr/local/lib/python2.7/site-packages/statsmodels/nonparametric/kernel_density.pyc in __init__(self, data, var_type, bw, defaults)
#     109         self.nobs, self.k_vars = np.shape(self.data)
#     110         if self.nobs <= self.k_vars:
# --> 111             raise ValueError("The number of observations must be larger " \
#     112                              "than the number of variables.")
#     113
#
# ValueError: The number of observations must be larger than the number of variables.

# %%
x = np.random.normal(size=10)
sns.distplot(x);
